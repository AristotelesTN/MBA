# %% [markdown]
# <a href="https://colab.research.google.com/github/AristotelesTN/MBA/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_excel('Dataset_ISRA_Agosto_Set_19_Modificado.xlsx')

# %%
columns = ['Featureset: FS5D-ImageBlobber','QC Time','Glass Type','Idx','Optic', 'TBF','TDF','RBF','Faint','Moire','Row','Column',
          'Date and Time','Date','Time','Side','Bank','Type','Panel UUID','UUID','Mech. Center CW','Bank ID','Camera ID','Mech. Center DW',
          'Mech. B.Box Left','Mech. B.Box Top','Mat. Center CW','Mat. Center DW','Mat. B.Box Left','Mat. B.Box Top','Generator','Featureset UUID',
          'Class ID','Class name','Image Center CW','Image Center DW','Filename','is Unique?','File','Idx.1','Time.1','Defect UUID','Inspected',
          'Use for Statistics','Comment','Row Caption (for Autoformat)','Glass Thickness','Sensitivity Area','Quality Relevant','Reject',
          'Rule Number','New Type UUID','All Fulfilled Rules','User_Feature_47','User_Feature_48','User_Feature_49','User_Feature_50','User_Feature_51',
          'User_Feature_52','User_Feature_53','User_Feature_54','User_Feature_55','User_Feature_56','User_Feature_57','User_Feature_58','User_Feature_59',
          'User_Feature_60','User_Feature_61','User_Feature_62','User_Feature_63']
df1 = df.drop(columns, axis=1)
print(len(columns))
# Out:
# 70

# %%
df1.isnull()
# Out:
#      Length QC Sheet  Net Width QC Sheet  ...  Manual Defect Class  New Type\nV83e_f
# 0              False               False  ...                False             False
# 1              False               False  ...                False             False
# 2              False               False  ...                False             False
# 3              False               False  ...                False             False
# 4              False               False  ...                False             False
# 5              False               False  ...                False             False
# 6              False               False  ...                False             False
# 7              False               False  ...                False             False
# 8              False               False  ...                False             False
# 9              False               False  ...                False             False
# 10             False               False  ...                False             False
# 11             False               False  ...                False             False
# 12             False               False  ...                False             False
# 13             False               False  ...                False             False
# 14             False               False  ...                False             False
# 15             False               False  ...                False             False
# 16             False               False  ...                False             False
# 17             False               False  ...                False             False
# 18             False               False  ...                False             False
# 19             False               False  ...                False             False
# 20             False               False  ...                False             False
# 21             False               False  ...                False             False
# 22             False               False  ...                False             False
# 23             False               False  ...                False             False
# 24             False               False  ...                False             False
# 25             False               False  ...                False             False
# 26             False               False  ...                False             False
# 27             False               False  ...                False             False
# 28             False               False  ...                False             False
# 29             False               False  ...                False             False
# ..               ...                 ...  ...                  ...               ...
# 411            False               False  ...                False             False
# 412            False               False  ...                False             False
# 413            False               False  ...                False             False
# 414            False               False  ...                False             False
# 415            False               False  ...                False             False
# 416            False               False  ...                False             False
# 417            False               False  ...                False             False
# 418            False               False  ...                False             False
# 419            False               False  ...                 True             False
# 420            False               False  ...                 True             False
# 421            False               False  ...                 True             False
# 422            False               False  ...                 True             False
# 423            False               False  ...                 True             False
# 424            False               False  ...                 True             False
# 425            False               False  ...                 True             False
# 426            False               False  ...                 True             False
# 427            False               False  ...                 True             False
# 428            False               False  ...                 True             False
# 429            False               False  ...                 True             False
# 430            False               False  ...                 True             False
# 431            False               False  ...                 True             False
# 432            False               False  ...                 True             False
# 433            False               False  ...                 True             False
# 434            False               False  ...                 True             False
# 435            False               False  ...                 True             False
# 436            False               False  ...                False             False
# 437            False               False  ...                 True             False
# 438            False               False  ...                False             False
# 439            False               False  ...                False             False
# 440            False               False  ...                 True             False
#
# [441 rows x 590 columns]

# %%
df1.head(2)
# Out:
#    Length QC Sheet  Net Width QC Sheet  ...  Manual Defect Class  New Type\nV83e_f
# 0           1100.1             3819.93  ...                  5.0         Top Speck
# 1           1100.1             3819.93  ...                  4.0            Bubble
#
# [2 rows x 590 columns]

# %%
df1.dtypes
# Out:
# Length QC Sheet        float64
# Net Width QC Sheet     float64
# Floatspeed m/min       float64
# Camera                   int64
# Width                  float64
# Length                 float64
# Area                   float64
# Diagonal               float64
# Type name               object
# Type ID                 object
# Image B.Box Left       float64
# Image B.Box Top          int64
# Image B.Box Width        int64
# Image B.Box Length       int64
# Image Area               int64
# Image Diagonal         float64
# Channel                  int64
# Resolution CW          float64
# Resolution DW          float64
# Flags                    int64
# No                       int64
# No 0                     int64
# Dist. Length BB        float64
# Dist. Width BB         float64
# Dist. Length Std       float64
# Dist. Width Std        float64
# Core Length            float64
# Core Width             float64
# Core Length 50%        float64
# Core Width 50%         float64
#                         ...
# User_Feature_38        float64
# User_Feature_39        float64
# User_Feature_40        float64
# User_Feature_41        float64
# User_Feature_42        float64
# User_Feature_43        float64
# User_Feature_44        float64
# User_Feature_45        float64
# User_Feature_46        float64
# Height.1               float64
# Thickness.1            float64
# Speed                  float64
# Optic Length           float64
# Optic Width            float64
# Core Length.1          float64
# Core Width.1           float64
# Camera.1                 int64
# Class                   object
# Type.1                  object
# Flow Pos [mm]          float64
# Cross Pos [mm]         float64
# QC Defect Type          object
# Flow Position          float64
# Cross position         float64
# Deformation Length     float64
# Deformation Width      float64
# Core Length.2           object
# Core Width.2           float64
# Manual Defect Class    float64
# New Type\nV83e_f        object
# Length: 590, dtype: object

# %%
df1.ndim
# Out:
# 2

# %%
df1.size
# Out:
# 260190

# %%
df1.shape
# Out:
# (441, 590)

# %%
df1.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-a9d1d5ebe4d2> in <module>()
# ----> 1 df1.mean(10)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7389         else:
#    7390             # TODO: Make other agg func handle axis=None properly
# -> 7391             axis = self._get_axis_number(axis)
#    7392             labels = self._get_agg_axis(axis)
#    7393             constructor = self._constructor
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# --> 361                          .format(axis, type(cls)))
#     362
#     363     @classmethod
#
# ValueError: No axis named 10 for object type <class 'type'>

# %%
df.loc()

# %%
sns.heatmap(df1.corr(),
            annot = True,
            fmt = '.2f',
            cmap='Blues')
plt.title('Correlação entre variáveis do dataset ISRA')
sns.figure(figsize=(100, 100))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-403f8ebd9f44> in <module>()
#       2             annot = True,
#       3             fmt = '.2f',
# ----> 4             cmap='Blues')
#       5 plt.title('Correlação entre variáveis do dataset ISRA')
#       6 sns.figure(figsize=(100, 100))
#
# /usr/local/lib/python3.6/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# /usr/local/lib/python3.6/dist-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     327         # Annotate the cells with the formatted values
#     328         if self.annot:
# --> 329             self._annotate_heatmap(ax, mesh)
#     330
#     331
#
# /usr/local/lib/python3.6/dist-packages/seaborn/matrix.py in _annotate_heatmap(self, ax, mesh)
#     244                 text_kwargs = dict(color=text_color, ha="center", va="center")
#     245                 text_kwargs.update(self.annot_kws)
# --> 246                 ax.text(x, y, annotation, **text_kwargs)
#     247
#     248     def _skip_ticks(self, labels, tickevery):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in text(self, x, y, s, fontdict, withdash, **kwargs)
#     720         else:
#     721             t = mtext.Text(
# --> 722                 x=x, y=y, text=s)
#     723
#     724         t.update(default)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     176         self._linespacing = linespacing
#     177         self.set_rotation_mode(rotation_mode)
# --> 178         self.update(kwargs)
#     179
#     180     def update(self, kwargs):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py in update(self, kwargs)
#     185         sentinel = object()  # bbox can be None, so use another sentinel.
#     186         bbox = kwargs.pop("bbox", sentinel)
# --> 187         super().update(kwargs)
#     188         if bbox is not sentinel:
#     189             self.set_bbox(bbox)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/artist.py in update(self, props)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# /usr/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# KeyboardInterrupt:
